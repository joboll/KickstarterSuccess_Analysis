# %%
import pandas as pd
from os import chdir
chdir('/Users/jonathanbeaulieu/Downloads/Kickstarter_2018-12-13T03_20_05_701Z')

# %%
col = ['backers_count', 'blurb', 'category', 'converted_pledged_amount',
       'country', 'created_at', 'creator', 'currency', 'currency_symbol',
       'currency_trailing_code', 'current_currency', 'deadline', 'fx_rate', 'goal', 'id', 
       'is_starred', 'launched_at', 'location',
       'name', 'pledged', 'spotlight', 'staff_pick', 'state', 'state_changed_at',
       'static_usd_rate', 'usd_pledged', 'usd_type']

filenames = [f"Kickstarter{i:03}.csv" for i in range(1,55)] #aussi possible en legacy ["%03d" % i for i in range(121)]

df = pd.read_csv('Kickstarter.csv', parse_dates=True, usecols=col)

for i in filenames:
    file = pd.read_csv(i, parse_dates=True, usecols=col)
    df = df.append(file)
    
df.shape
df.head()
df.tail()
# Out:
#       backers_count                                              blurb  \
# 1345             25  After 10 years of working and a successful pre...
# 1346            181  La primera aplicación móvil, gratuita y biling...
# 1347            287  iPhone light accessory for night photography. ...
# 1348             94  This is a project that 100% reflects the phras...
# 1349              4  Vinyl decorations taken to the next level.\n\n...
#
#                                                category  \
# 1345  {"id":24,"name":"Performance Art","slug":"art/...
# 1346  {"id":1,"name":"Art","slug":"art","position":1...
# 1347  {"id":52,"name":"Hardware","slug":"technology/...
# 1348  {"id":37,"name":"Country & Folk","slug":"music...
# 1349  {"id":27,"name":"Graphic Design","slug":"desig...
#
#       converted_pledged_amount country  created_at  \
# 1345                      6511      US  1335216463
# 1346                     14159      MX  1541625703
# ...

# %%
df['created_at'] = pd.to_datetime(df['created_at'], unit='s')
df['launched_at'] = pd.to_datetime(df['launched_at'], unit='s')
df['state_changed_at'] = pd.to_datetime(df['state_changed_at'], unit='s')
df['deadline'] = pd.to_datetime(df['deadline'], unit='s')

df.head()
# Out:
#    backers_count                                              blurb  \
# 0            170  A documentary about two circuses in remote cor...
# 1             10  A multi-media IPad book telling the true story...
# 2              0  We are college students that get drunk and the...
# 3              0  its Ali bangerz,its time to stand up for other...
# 4             62  A young neuroscientist attempts to reconnect w...
#
#                                             category  \
# 0  {"id":30,"name":"Documentary","slug":"film & v...
# 1  {"id":46,"name":"Children's Books","slug":"pub...
# 2  {"id":357,"name":"Audio","slug":"journalism/au...
# 3  {"id":44,"name":"World Music","slug":"music/wo...
# 4  {"id":30,"name":"Documentary","slug":"film & v...
#
#    converted_pledged_amount country          created_at  \
# 0                     27455      US 2012-06-12 18:30:42
# 1                       535      US 2012-11-03 11:10:26
# 2                         0      CA 2014-11-13 22:20:56
# ...

# %%
df.set_index('created_at', inplace=True)
df.head()
# Out:
#                      backers_count  \
# created_at
# 2012-06-12 18:30:42            170
# 2012-11-03 11:10:26             10
# 2014-11-13 22:20:56              0
# 2015-11-04 19:18:23              0
# 2010-09-09 03:38:56             62
#
#                                                                  blurb  \
# created_at
# 2012-06-12 18:30:42  A documentary about two circuses in remote cor...
# 2012-11-03 11:10:26  A multi-media IPad book telling the true story...
# 2014-11-13 22:20:56  We are college students that get drunk and the...
# 2015-11-04 19:18:23  its Ali bangerz,its time to stand up for other...
# 2010-09-09 03:38:56  A young neuroscientist attempts to reconnect w...
#
#                                                               category  \
# created_at
# 2012-06-12 18:30:42  {"id":30,"name":"Documentary","slug":"film & v...
# 2012-11-03 11:10:26  {"id":46,"name":"Children's Books","slug":"pub...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 207227 entries, 2012-06-12 18:30:42 to 2013-11-06 23:15:58
# Data columns (total 29 columns):
# backers_count               207227 non-null int64
# blurb                       207217 non-null object
# category                    207227 non-null object
# converted_pledged_amount    207227 non-null int64
# country                     207227 non-null object
# creator                     207227 non-null object
# currency                    207227 non-null object
# currency_symbol             207227 non-null object
# currency_trailing_code      207227 non-null bool
# current_currency            207227 non-null object
# deadline                    207227 non-null int64
# disable_communication       207227 non-null bool
# friends                     216 non-null object
# fx_rate                     207227 non-null float64
# goal                        207227 non-null float64
# id                          207227 non-null int64
# ...

# %%
import json
df_test = pd.read_csv('Kickstarter.csv', parse_dates=True, usecols=col)

# Parse CSV where one of the fields is a nested JSON object, stored as a string
stdf = df_test['category'].apply(json.loads) # Cast les valeurs de 'category' de str à dict
df_cat = pd.DataFrame(stdf.tolist()) # or stdf.apply(pd.Series)

# df.join(df['stats'].apply(json.loads).apply(pd.Series))

df_cat.head(1)
# Out:
#       color  id         name  parent_id  position                      slug  \
# 0  16734574  30  Documentary       11.0         4  film & video/documentary
#
#                                                 urls
# 0  {'web': {'discover': 'http://www.kickstarter.c...

# %%
df_test = pd.read_csv('Kickstarter.csv', parse_dates=True, usecols=col)
#dic = df_test.iloc[:1,2].values
dic = df_test['category']

#print(dic)
type(dic[0])
# Out:
# str

# %%
type(stdf[0])
# Out:
# dict

# %%
#id11 = df_cat[df_cat['id'] == 30]

#id11 = df_cat.id == 30
id11 = df_cat[df_cat['id'] == 11]
#id11.count()
id11.head()
# Out:
# Empty DataFrame
# Columns: [color, id, name, parent_id, position, slug, urls]
# Index: []

# %%
chdir('/Users/jonathanbeaulieu/Desktop')
df.to_pickle('KS_df_clean_partiel.zip')
